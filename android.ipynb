# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Android data best games

# %%
file_data = 'df_1.csv'

# %%
df = pd.read_csv(file_data, sep = ',')

# %%
df
# Out:
#      Unnamed: 0                               Title  \
# 0             0                AdVenture Capitalist
# 1             1                 AdVenture Communist
# 2             2                  Adventures of Mana
# 3             3                 After Burner Climax
# 4             4                          Alien Hive
# ..          ...                                 ...
# 220         220  The Walking Dead: Road to Survival
# 221         221                  XCOM: Enemy Within
# 222         222         Yo-kai Watch: Wibble Wobble
# 223         223                Yu-Gi-Oh! Duel Links
# 224         224                               title
#
#                   Developer(s)  Publisher(s)  \
# 0      Hyper Hippo Productions    Kongregate
# 1      Hyper Hippo Productions    Kongregate
# 2                  Square Enix   Square Enix
# 3                     Sega AM2          Sega
# 4                    Appxplore           NaN
# ..                         ...           ...
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Title', 'Developer(s)', 'Publisher(s)', 'Genre',
#        'Release date', 'ref'],
#       dtype='object')

# %%
df.pop('Unnamed: 0')
# Out:
# 0        0
# 1        1
# 2        2
# 3        3
# 4        4
#       ...
# 220    220
# 221    221
# 222    222
# 223    223
# 224    224
# Name: Unnamed: 0, Length: 225, dtype: int64

# %%
df
# Out:
#                                   Title               Developer(s)  \
# 0                  AdVenture Capitalist    Hyper Hippo Productions
# 1                   AdVenture Communist    Hyper Hippo Productions
# 2                    Adventures of Mana                Square Enix
# 3                   After Burner Climax                   Sega AM2
# 4                            Alien Hive                  Appxplore
# ..                                  ...                        ...
# 220  The Walking Dead: Road to Survival  IUGO Mobile Entertainment
# 221                  XCOM: Enemy Within              Firaxis Games
# 222         Yo-kai Watch: Wibble Wobble                    Level-5
# 223                Yu-Gi-Oh! Duel Links                     Konami
# 224                               title               developer(s)
#
#      Publisher(s)                                 Genre  \
# 0      Kongregate                           Incremental
# ...
